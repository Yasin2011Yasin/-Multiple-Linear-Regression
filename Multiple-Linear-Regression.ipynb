# %% [markdown]
# # 🏠 House Price Prediction — Regression Portfolio Project
# created by: **Yasin Dehghani**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Checking dataset

# %%
df=pd.read_csv('housing_data.csv')
df
# Out:
#     area_m2  num_rooms  age_years  distance_to_center_km  has_parking  \
# 0        75          2         15                    3.2            0
# 1       120          3          5                    1.8            1
# 2        55          1         25                    8.5            0
# 3        90          2         10                    4.1            1
# 4       200          4          2                    0.9            1
# 5        65          2         20                    6.3            0
# 6       150          3          8                    2.5            1
# 7        45          1         30                   10.2            0
# 8       110          3         12                    3.7            1
# 9       180          4          3                    1.5            1
# 10       80          2         18                    5.0            0
# 11      130          3          6                    2.2            1
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   area_m2                40 non-null     int64
#  1   num_rooms              40 non-null     int64
#  2   age_years              40 non-null     int64
#  3   distance_to_center_km  40 non-null     float64
#  4   has_parking            40 non-null     int64
#  5   has_elevator           40 non-null     int64
#  6   neighborhood_quality   40 non-null     int64
#  7   price_million_toman    40 non-null     int64
# dtypes: float64(1), int64(7)
# memory usage: 2.6 KB
#           area_m2  num_rooms  age_years  distance_to_center_km  has_parking  \
# count   40.000000  40.000000  40.000000              40.000000    40.000000
# mean   106.000000   2.550000  13.200000               4.452500     0.575000
# std     45.474704   1.011473   8.694826               2.911779     0.500641
# ...

# %% [markdown]
# # Praparing Data

# %%
X=df.drop('price_million_toman', axis=1)

Y=df['price_million_toman']

# %% [markdown]
# ## Make train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.2, random_state=42)

# %% [markdown]
# # building model

# %%
from sklearn.linear_model import LinearRegression

# %%
md=LinearRegression()
md.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # scoring model

# %%
from sklearn.metrics import r2_score

# %%
Y_pred=md.predict(X_test)

# %%
r_score=r2_score(Y_pred, Y_test)
print('r2 score:',r_score)
# Out:
# r2 score: 0.9915563657262263

# %% [markdown]
# And now we build a model to predict house price in iran i hope it'll be useful for you
